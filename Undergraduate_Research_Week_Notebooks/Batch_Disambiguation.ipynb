# %% [markdown]
# # Disambiguation Notebook
#
# - In this notebook, We will be utilizing OpenAI's Batch Processsing in order to run three processes over an entire dataset:
#   - A pronoun disambiguation prompt
#   - A fine-tuned model that identifies incomplete questions
#   - A prompt that adds needed context to incomplete questions

# %% [markdown]
# # Batch Processing
#
# This code demonstrates how you can submit batch processing jobs to openai. Batch processing is 50% cheaper than synchronous processing, making it idea for processing large batches of data.
#
# ### Patch Processing documentation
# - https://platform.openai.com/docs/guides/batch
#
# ### API reference
# - https://platform.openai.com/docs/api-reference/batch
#
# ### Pricing:
# - https://openai.com/api/pricing

# %% [markdown]
# # Batch Processing Utils

# %%
# Batch Processing
import re
import os
import json
import time
import pandas as pd
from typing import List, Optional, Type
from openai import OpenAI
from pydantic import BaseModel
from tqdm import tqdm

class BatchProcessor:
    def __init__(self, api_key: str, response_format: Type[BaseModel] = None, llm_model: str = 'gpt-4o-mini'):
        self.client = OpenAI(api_key=api_key)
        self.tasks = []
        self.batch_response = None
        self.schema = generate_schema(response_format)
        self.response_format = response_format
        self.llm_model = llm_model

    def set_schema(self, schema: dict):
        self.schema = schema

    def create_tasks(self,
                     df: pd.DataFrame,
                     system_prompt: str,
                     input_prompt: str
                     ):
        self.tasks = [
            {
                "custom_id": f"task_{i}",
                "method": "POST",
                "url": "/v1/chat/completions",
                "body": {
                    "model": self.llm_model,
                    "temperature": 0.7, # set the temperature
                    "messages": [
                        {"role": "system", "content": system_prompt},
                        {"role": "user", "content": input_prompt.format(**row.to_dict())}
                    ],
                    **(
                        {"response_format": {"type": "json_schema", "json_schema": self.schema["json_schema"]}}
                        if self.schema else {}
                    )
                }
            }
            for i, row in df.iterrows()
        ]
    def _save_file(self, filename: str, content: str, overwrite: bool = False) -> None:
        """
        Centralized file saving utility with overwrite protection

        Args:
            filename (str): Path to save file
            content (str): Content to write
            overwrite (bool): Allow overwriting existing files

        Raises:
        FileExistsError: If file exists and overwrite=False
        PermissionError: If unable to write to file
        ValueError: If filename is invalid
        """
        if os.path.exists(filename) and not overwrite:
            raise FileExistsError(f"File {filename} already exists")

        try:
            dir_path = os.path.dirname(filename)
            if dir_path and not os.path.exists(dir_path):
                os.makedirs(dir_path)

            with open(filename, 'w') as f:
                f.write(content)

        except Exception as e:
            print(f"Error saving file: {e}")
            raise

    def write_tasks_to_file(self, filename="batch_tasks.jsonl", overwrite=False):
        content = '\n'.join(json.dumps(task) for task in self.tasks)
        self._save_file(filename, content, overwrite)

    def upload_file(self, filename="batch_tasks.jsonl"):
        file_response = self.client.files.create(
            file=open(filename, 'rb'),
            purpose='batch'
        )
        return file_response.id

    def create_batch_job(self, file_id):
        self.batch_response = self.client.batches.create(
            input_file_id=file_id,
            endpoint="/v1/chat/completions",
            completion_window="24h"
        )
        batch_id = self.batch_response.id
        print(f"Batch created with ID: {batch_id}")
        return batch_id

    def _get_batch_status(self, batch_id: Optional[str] = None):
        if batch_id:
            return self.client.batches.retrieve(batch_id)
        elif self.batch_response:
            return self.client.batches.retrieve(self.batch_response.id)
        else:
            raise Exception("No batch_id provided and no active batch found.")

    def monitor_batch(self, batch_id: Optional[str] = None, interval: Optional[int] = 1000):
        batch_status = self._get_batch_status(batch_id)
        print("Monitoring batch job...")
        while True:
            batch_status = self.client.batches.retrieve(batch_status.id)
            if batch_status.status == 'completed':
                print("Batch job completed.")
                return batch_status
            elif batch_status.status == 'failed':
                print(f"Batch job failed: {batch_status.errors}")
                break
            else:
                print(f"Batch job is still processing... Status: {batch_status.status}")
            time.sleep(interval)

    def download_results(self, output_filename="batch_results.jsonl", overwrite=False, batch_id: Optional[str] = None):
        batch_status = self._get_batch_status(batch_id)

        if batch_status.status != 'completed':
            print(f"Batch status: {batch_status.status}")
            if hasattr(batch_status, 'errors'):
                print(f"Errors: {batch_status.errors}")
            return

        if hasattr(batch_status, 'output_file_id') and batch_status.output_file_id:
            result_file_id = batch_status.output_file_id
            print(f"Downloading file with ID: {result_file_id}")

            try:
                result_content = self.client.files.content(result_file_id)
                self._save_file(output_filename, result_content.text, overwrite)
                print("Results downloaded to file:", output_filename)
            except Exception as e:
                print(f"Error downloading results: {e}")
        else:
            print(f"Batch completed but no result file generated. Status details: {getattr(batch_status, 'status_details', None)}")

    def parse_results(self, filename="batch_results.jsonl"):
        results = []
        try:
            with open(filename, 'r') as f:
                for line in f:
                    try:
                        result = json.loads(line)
                        content = result.get('response', {}).get('body', {}).get('choices', [{}])[0].get('message', {}).get('content', None)
                        custom_id = result.get('custom_id')

                        # Extract only the numerical part after 'task_'
                        if custom_id:
                            match = re.search(r'task_(\d+)$', custom_id)
                            if match:
                                custom_id = int(match.group(1))

                        def normalize_quotes(content: str) -> str:
                            content = content.replace('“', '"').replace('”', '"')
                            content = content.replace('‘', "'").replace('’', "'")
                            return content

                        content = normalize_quotes(content)

                        if content:
                            if content.strip().startswith("{") and not content.strip().endswith("}"):
                                print(f"Attempting to repair truncated content...")
                                if content.strip().endswith('",'):
                                    content = content.rstrip('",') + '"},'
                                elif not content.strip().endswith('"'):
                                    content += '"}'
                                else:
                                    content += '}'

                            content = content.replace('","}', '"}')

                            # Parse using Pydantic model and add custom_id
                            parsed_result = self.response_format.model_validate_json(content)
                            parsed_data = parsed_result.model_dump()
                            parsed_data['custom_id'] = custom_id  # Add numeric custom_id

                            results.append(parsed_data)

                    except json.JSONDecodeError as e:
                        print(f"Error parsing JSON: {e}")
                        print(f"Raw content: {content}")

                    except Exception as e:
                        print(f"Error parsing result with model {self.response_format.__name__}: {e}")
                        print(f"Raw content: {content}")

        except FileNotFoundError:
            print(f"Results file '{filename}' not found.")

        if results:
            # Normalize into a DataFrame using dynamic keys
            df = pd.json_normalize(results)
            return df
        else:
            print("No valid results found.")
            return pd.DataFrame()



    def cancel_batch(self, batch_id: Optional[str] = None):
        batch_status = self._get_batch_status(batch_id)

        if batch_status.status in ["completed", "failed", "cancelled"]:
            print(f"Cannot cancel batch with status '{batch_status.status}'")
            return

        try:
            self.client.batches.cancel(batch_status.id)
            print(f"Batch '{batch_status.id}' has been cancelled.")
        except Exception as e:
            print(f"Error cancelling batch: {e}")

# Schema generator
from openai.lib._parsing._completions import type_to_response_format_param

def generate_schema(model):
    schema = type_to_response_format_param(model)
    return {"type": "json_schema", "json_schema": schema['json_schema']}

# %%
import spacy

nlp = spacy.load("en_core_web_sm")

def tokenize(text):
    # Tokenize the text
    doc = nlp(text)
    return [token.text for token in doc]

# %% [markdown]
# # Mount Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from google.colab import auth
auth.authenticate_user()

import gspread
from google.auth import default
creds, _ = default()

gc = gspread.authorize(creds)

# %% [markdown]
# # Part 1: Disambiguation
#
# We will use the base model to disambiguate pronouns

# %% [markdown]
# ## Import Data

# %%
import pandas as pd

#sheet_id = "1E5gKTygkxLXyYsbAjR5trxaDgDx90VfHgsXlZExcnQA" # Boder Part A
sheet_id = "1VUMcV3_sv6GMAprTkNW2-RAsgRWpGDu5dxwvxqxWNrY" # Boder Part B Sheet name: Preprocessing Results- Version B
worksheet_name = "IsQuestion"
sh = gc.open_by_key(sheet_id)
worksheet = sh.worksheet(worksheet_name)
full_df = pd.DataFrame(worksheet.get_all_records())

# %%
full_df
# Out:
#               index  file_part  file_num     Time          Names      Speaker  \
# 0          4  49911          4         1  0:01:54       Ilmar A.  David Boder
# 1          6  49913          6         1  0:02:38       Ilmar A.  David Boder
# 2          8  49915          8         1  0:03:19       Ilmar A.  David Boder
# 3         10  49917         10         1  0:03:31       Ilmar A.  David Boder
# 4         12  49919         12         1  0:03:38       Ilmar A.  David Boder
# ...      ...    ...        ...       ...      ...            ...          ...
# 15803  52856  48117        479       119  0:28:21  Janine Binder  David Boder
# 15804  52858  48119        481       119  0:28:23  Janine Binder  David Boder
# 15805  52860  48121        483       119  0:28:55  Janine Binder  David Boder
# 15806  52862  48123        485       119  0:29:02  Janine Binder  David Boder
# 15807  52870  48131        493       119  0:29:48  Janine Binder  David Boder
#
#                                            original_text  \
# 0      Let me tell you frankly  : Do not tell me some...
# 1      … until today. But to you personally. Where di...
# 2      How old were you then? What grade were you in ...
# 3           What means “first grade”? The highest grade?
# 4                                     … of the “Volks-”?
# ...                                                  ...
# 15803              Was she Jewish, a Jewish girl friend?
# 15804           And she too was there as an Aryan woman?
# 15805                                     Found courage?
# 15806                                                So?
# 15807                             Who were they, French?
#
#                                                BrackInfo           IsKeep  \
# 0      [('[', '?', ']'), ('[', 'possibly “we are info...  ['O', 'O', 'Y']
# 1           [('[', 'Bend down to the microphone?', ']')]            ['N']
# 2                                                     []               []
# 3                                                     []               []
# 4                                                     []               []
# ...                                                  ...              ...
# 15803                                                 []               []
# 15804                                                 []               []
# 15805                                                 []               []
# 15806                                                 []               []
# 15807                                                 []               []
#
#                                    Info  is_interviewee  text_length  \
# 0                                    []               0           88
# 1      ['Bend down to the microphone?']               0           54
# 2                                    []               0           11
# 3                                    []               0            7
# 4                                    []               0            4
# ...                                 ...             ...          ...
# 15803                                []               0            7
# 15804                                []               0            9
# 15805                                []               0            2
# 15806                                []               0            1
# 15807                                []               0            4
#
#        needs_edits                                               text  \
# 0                1  Let me tell you frankly: Do not tell me some g...
# 1                0  … until today. But to you personally. Where di...
# 2                0  How old were you then? What grade were you in ...
# 3                0       What means “first grade”? The highest grade?
# 4                0                                 … of the “Volks-”?
# ...            ...                                                ...
# 15803            0              Was she Jewish, a Jewish girl friend?
# 15804            0           And she too was there as an Aryan woman?
# 15805            0                                     Found courage?
# 15806            0                                                So?
# 15807            0                             Who were they, French?
#
#                                                  context  token_count  \
# 0      INTERVIEWER:  Spool 152A, Spool 152A. Ilmar A....          165
# 1      INTERVIEWER:  Spool 152A, Spool 152A. Ilmar A....          262
# 2      INTERVIEWER:  Spool 152A, Spool 152A. Ilmar A....          361
# 3      INTERVIEWER:  Spool 152A, Spool 152A. Ilmar A....          409
# 4      INTERVIEWER:  Spool 152A, Spool 152A. Ilmar A....          441
# ...                                                  ...          ...
# 15803  INTERVIEWER: Who liberated you in Stuttgart?\n...          500
# 15804  SUBJECT: Yes.\nINTERVIEWER: The French liberat...          493
# 15805  SUBJECT: No, no, no. But one feels, one can … ...          495
# 15806  SUBJECT: Yes. But these were all in Polish.\nI...          488
# 15807  INTERVIEWER: Yes.\nSUBJECT: I was afraid of th...          448
#
#       is_question is_command
# 0            TRUE      FALSE
# 1            TRUE      FALSE
# 2            TRUE      FALSE
# 3            TRUE      FALSE
# 4            TRUE      FALSE
# ...           ...        ...
# 15803        TRUE      FALSE
# 15804        TRUE      FALSE
# 15805        TRUE      FALSE
# 15806        TRUE      FALSE
# 15807        TRUE      FALSE
#
# [15808 rows x 19 columns]

# %%
input_df = full_df[['text', 'context']]

blacklist = ['Aha. Nu?','Yes?', 'What does that mean?','Nu?', 'Yes. And?', 'unintelligible ?', 'And?', 'Go on.', 'Yes? Nu?', 'Yes, and then?', 'Yes, go on.', 'OK?', 'Yes. And then?', 'Yes. Well?', 'I see. Well?', 'What?', 'Nu, go on.', 'Well, go on.', 'Yes, nu?', 'Yes, well?' 'Yes. Nu?', 'Yes, and?', 'Well?', 'Hm. Nu?', 'Mhm?']
input_df = input_df[~input_df['text'].isin(blacklist)]
input_df
# Out:
#                                                     text  \
# 0      Let me tell you frankly: Do not tell me some g...
# 1      … until today. But to you personally. Where di...
# 2      How old were you then? What grade were you in ...
# 3           What means “first grade”? The highest grade?
# 4                                     … of the “Volks-”?
# ...                                                  ...
# 15803              Was she Jewish, a Jewish girl friend?
# 15804           And she too was there as an Aryan woman?
# 15805                                     Found courage?
# 15806                                                So?
# 15807                             Who were they, French?
#
#                                                  context
# 0      INTERVIEWER:  Spool 152A, Spool 152A. Ilmar A....
# 1      INTERVIEWER:  Spool 152A, Spool 152A. Ilmar A....
# 2      INTERVIEWER:  Spool 152A, Spool 152A. Ilmar A....
# 3      INTERVIEWER:  Spool 152A, Spool 152A. Ilmar A....
# 4      INTERVIEWER:  Spool 152A, Spool 152A. Ilmar A....
# ...                                                  ...
# 15803  INTERVIEWER: Who liberated you in Stuttgart?\n...
# 15804  SUBJECT: Yes.\nINTERVIEWER: The French liberat...
# 15805  SUBJECT: No, no, no. But one feels, one can … ...
# 15806  SUBJECT: Yes. But these were all in Polish.\nI...
# 15807  INTERVIEWER: Yes.\nSUBJECT: I was afraid of th...
#
# [14290 rows x 2 columns]

# %% [markdown]
# Define Functions for processing data

# %% [markdown]
# ## Define Schema

# %%
# Define Schema and Prompt

from pydantic import BaseModel, Field
from typing import List, Literal

class ResponseFormat(BaseModel):
    chain_of_thought: str = Field(..., description="Step-by-step reasoning behind the response.")
    contains_unresolved_pronoun: bool = Field(..., description="True if the Question contains at least one ambiguous pronoun that requires resolution; False otherwise, or if the pronoun would refer to the interviewer or interviewee.")
    enough_context_provided: bool = Field(..., description="True if there is sufficient context to resolve the pronoun(s) in the Question; False if more context is needed.")
    disambiguated_text: str = Field(..., description="If pronoun resolution is needed, and sufficient Previous Context is provided, rewrite the Question, referring to the interviewee as 'you'. Otherwise, respond with an empty string.")

system_prompt = "Your role is to process data factually without generating hallucinations or fabrications"

input_prompt = """Task:
The following text is from an interview.
Your task is to resolve pronouns in the Question with proper nouns or noun phrases based on the Previous Context.
Determine whether there are pronouns representing subjects or objects in the Question that need to be disambiguated.
Focus on pronouns like "he," "him," "she," "her," "they," and "them,", as these likely refer to subjects or objects mentioned earlier. Pronouns such as "you" or "I" refer to the interviewee and interviewer and do not need to be disambiguated. Phrases like "that" also don't need to be disambiguated.
Determine whether there is enough Previous Context to resolve the pronoun(s) in the Question.
If the pronouns can be resolved using the Previous Context, revise the Question.  Refer to the interviewee as 'you'.
If not, respond with an empty string.


Previous Context: {text}

Question: {context}
"""

# %% [markdown]
# ## Run Batch Process

# %%
#@title Run Batch Process
from google.colab import userdata
import os

#set environment
os.environ['OPENAI_API_KEY'] = userdata.get('OPEN_AI_PROJECT_KEY')

# %%
# Initialize the processor
processor = BatchProcessor(api_key=os.getenv('OPENAI_API_KEY'), response_format=ResponseFormat)

#Create Batch Process Compatible Schema
schema = generate_schema(ResponseFormat)
processor.set_schema(schema)

# Define Data to Process
process_df = input_df
#process_df = df.sample(10).copy() # Test on a sample

# Assemble Batch Processing File
processor.create_tasks(process_df, system_prompt, input_prompt)
processor.write_tasks_to_file(filename="batch_tasks_disambiguation.jsonl")

# Upload tasks
file_id = processor.upload_file(filename="batch_tasks_disambiguation.jsonl")

# Create batch job
processor.create_batch_job(file_id)

# %% [markdown]
# Copy the batch id from the output and paste it ito the code.

# %%
BATCH_ID = 'batch_67e26e414144819099b681d01efc6879' #replace with your batch_id

# %%
# Cancel batch job
#processor.cancel_batch(batch_id = BATCH_ID)

# %%
# Monitor progress
processor = BatchProcessor(api_key=os.getenv('OPENAI_API_KEY'), response_format=ResponseFormat)
processor.monitor_batch(batch_id = BATCH_ID)

# %%
# Download results from Batch ID
processor = BatchProcessor(api_key=os.getenv('OPENAI_API_KEY'),  response_format=ResponseFormat)
processor.download_results(output_filename='batch_results_disambiguation.json', batch_id = BATCH_ID, overwrite=True)

# %%
# Parse results
processor = BatchProcessor(api_key=os.getenv('OPENAI_API_KEY'), response_format=ResponseFormat)
results_df = processor.parse_results(filename='batch_results_disambiguation.json')

# %%
# join results to original data frame on index
#df = df.reset_index() # You might need to reset index?
disambiguated_df = full_df.join(results_df.set_index('custom_id'), how='left')
disambiguated_df

# %%
disambiguated_df.to_csv("disambiguation_results.csv")

from google.colab import files
files.download("disambiguation_results.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-b2c68e53e634> in <cell line: 0>()
# ----> 1 df_combined.to_csv("rewriting_results.csv")
#       2
#       3 from google.colab import files
#       4 files.download("rewriting_results.csv")
#
# NameError: name 'df_combined' is not defined

# %% [markdown]
# # Part 2: Categorization
#
# now, we will utilize a fine-tuned model to identify questions that are incomplete and need rewriting

# %% [markdown]
# ## Import Data

# %%
# Run if you did the first part in a separate runtime

sheet_id = "1fXmcPPn7j5kg4ALdE5P2ZPgfaC_UpceuO9eDqWb_dP8" #Version A/B Results
worksheet_name = "Sheet1"
sh = gc.open_by_key(sheet_id)
worksheet = sh.worksheet(worksheet_name)
disambiguated_df = pd.DataFrame(worksheet.get_all_records())
disambiguated_df = disambiguated_df.set_index('a', drop = True)
disambiguated_df
# Out:
#        index  file_part  file_num     Time          Names      Speaker  \
# a
# 4      49911          4         1  0:01:54       Ilmar A.  David Boder
# 6      49913          6         1  0:02:38       Ilmar A.  David Boder
# 8      49915          8         1  0:03:19       Ilmar A.  David Boder
# 10     49917         10         1  0:03:31       Ilmar A.  David Boder
# 12     49919         12         1  0:03:38       Ilmar A.  David Boder
# ...      ...        ...       ...      ...            ...          ...
# 52856  48117        479       119  0:28:21  Janine Binder  David Boder
# 52858  48119        481       119  0:28:23  Janine Binder  David Boder
# 52860  48121        483       119  0:28:55  Janine Binder  David Boder
# 52862  48123        485       119  0:29:02  Janine Binder  David Boder
# 52870  48131        493       119  0:29:48  Janine Binder  David Boder
#
#                                            original_text  \
# a
# 4      Let me tell you frankly  : Do not tell me some...
# 6      … until today. But to you personally. Where di...
# 8      How old were you then? What grade were you in ...
# 10          What means “first grade”? The highest grade?
# 12                                    … of the “Volks-”?
# ...                                                  ...
# 52856              Was she Jewish, a Jewish girl friend?
# 52858           And she too was there as an Aryan woman?
# 52860                                     Found courage?
# 52862                                                So?
# 52870                             Who were they, French?
#
#                                                BrackInfo           IsKeep  \
# a
# 4      [('[', '?', ']'), ('[', 'possibly “we are info...  ['O', 'O', 'Y']
# 6           [('[', 'Bend down to the microphone?', ']')]            ['N']
# 8                                                     []               []
# 10                                                    []               []
# 12                                                    []               []
# ...                                                  ...              ...
# 52856                                                 []               []
# 52858                                                 []               []
# 52860                                                 []               []
# 52862                                                 []               []
# 52870                                                 []               []
#
#                                    Info  ...  \
# a                                        ...
# 4                                    []  ...
# 6      ['Bend down to the microphone?']  ...
# 8                                    []  ...
# 10                                   []  ...
# 12                                   []  ...
# ...                                 ...  ...
# 52856                                []  ...
# 52858                                []  ...
# 52860                                []  ...
# 52862                                []  ...
# 52870                                []  ...
#
#                                                  context  token_count  \
# a
# 4      INTERVIEWER:  Spool 152A, Spool 152A. Ilmar A....          165
# 6      INTERVIEWER:  Spool 152A, Spool 152A. Ilmar A....          262
# 8      INTERVIEWER:  Spool 152A, Spool 152A. Ilmar A....          361
# 10     INTERVIEWER:  Spool 152A, Spool 152A. Ilmar A....          409
# 12     INTERVIEWER:  Spool 152A, Spool 152A. Ilmar A....          441
# ...                                                  ...          ...
# 52856  INTERVIEWER: Who liberated you in Stuttgart?\n...          500
# 52858  SUBJECT: Yes.\nINTERVIEWER: The French liberat...          493
# 52860  SUBJECT: No, no, no. But one feels, one can … ...          495
# 52862  SUBJECT: Yes. But these were all in Polish.\nI...          488
# 52870  INTERVIEWER: Yes.\nSUBJECT: I was afraid of th...          448
#
#        is_question is_command  \
# a
# 4             TRUE      FALSE
# 6             TRUE      FALSE
# 8             TRUE      FALSE
# 10            TRUE      FALSE
# 12            TRUE      FALSE
# ...            ...        ...
# 52856         TRUE      FALSE
# 52858         TRUE      FALSE
# 52860         TRUE      FALSE
# 52862         TRUE      FALSE
# 52870         TRUE      FALSE
#
#                                         chain_of_thought  \
# a
# 4      In the Question, the pronouns 'you' and 'your'...
# 6      In the provided Previous Context, the subject ...
# 8      In the provided context, the interviewee is Mr...
# 10     The Question contains the pronoun 'the highest...
# 12     The question contains the pronoun "the" which ...
# ...                                                  ...
# 52856  In the Previous Context, the interviewee menti...
# 52858  In the Question, the pronoun "she" likely refe...
# 52860  The question 'Found courage?' does not contain...
# 52862  The question 'So?' is too vague and does not c...
# 52870  In the Previous Context, the term 'they' in th...
#
#        contains_unresolved_pronoun enough_context_provided  \
# a
# 4                            FALSE                    TRUE
# 6                            FALSE                    TRUE
# 8                            FALSE                    TRUE
# 10                            TRUE                   FALSE
# 12                            TRUE                   FALSE
# ...                            ...                     ...
# 52856                         TRUE                   FALSE
# 52858                         TRUE                    TRUE
# 52860                        FALSE                    TRUE
# 52862                        FALSE                    TRUE
# 52870                         TRUE                    TRUE
#
#                                       disambiguated_text was_disambiguated  \
# a
# 4      Let me tell you frankly: Do not tell me some g...              TRUE
# 6      ... until today. But to you personally, Mr. Il...              TRUE
# 8      How old were you then? What grade were you in ...              TRUE
# 10                                                                   FALSE
# 12                                                                   FALSE
# ...                                                  ...               ...
# 52856                                                                FALSE
# 52858  And your girlfriend too was there as an Aryan ...              TRUE
# 52860                                                                FALSE
# 52862                                                                FALSE
# 52870                      Who were the French soldiers?              TRUE
#
#                                       text_for_rewriting
# a
# 4      Let me tell you frankly: Do not tell me some g...
# 6      … until today. But to you personally. Where di...
# 8      How old were you then? What grade were you in ...
# 10          What means “first grade”? The highest grade?
# 12                                    … of the “Volks-”?
# ...                                                  ...
# 52856              Was she Jewish, a Jewish girl friend?
# 52858  And your girlfriend too was there as an Aryan ...
# 52860                                     Found courage?
# 52862                                                So?
# 52870                      Who were the French soldiers?
#
# [15808 rows x 24 columns]

# %%
# Blacklisted Questions and Long Questions are automatic Non rewrites and should not be inputted into the df

blacklist = ['Aha. Nu?','Yes?', 'What does that mean?','Nu?', 'Yes. And?', 'unintelligible ?', 'And?', 'Go on.', 'Yes? Nu?', 'Yes, and then?', 'Yes, go on.', 'OK?', 'Yes. And then?', 'Yes. Well?', 'I see. Well?', 'What?', 'Nu, go on.', 'Well, go on.', 'Yes, nu?', 'Yes, well?', 'Yes. Nu?', 'Yes, and?', 'Well?', 'Hm. Nu?', 'Mhm?', '?']
for index, row in disambiguated_df.iterrows():
  if row['text_for_rewriting'] in blacklist:
    disambiguated_df.at[index, 'decision'] = False
    disambiguated_df.at[index, 'reason'] = 'Blacklisted'
  if row['text_length'] >= 20:
    disambiguated_df.at[index, 'decision'] = False
    disambiguated_df.at[index, 'reason'] = 'Too long'
disambiguated_df
# Out:
#        index  file_part  file_num     Time          Names      Speaker  \
# a
# 4      49911          4         1  0:01:54       Ilmar A.  David Boder
# 6      49913          6         1  0:02:38       Ilmar A.  David Boder
# 8      49915          8         1  0:03:19       Ilmar A.  David Boder
# 10     49917         10         1  0:03:31       Ilmar A.  David Boder
# 12     49919         12         1  0:03:38       Ilmar A.  David Boder
# ...      ...        ...       ...      ...            ...          ...
# 52856  48117        479       119  0:28:21  Janine Binder  David Boder
# 52858  48119        481       119  0:28:23  Janine Binder  David Boder
# 52860  48121        483       119  0:28:55  Janine Binder  David Boder
# 52862  48123        485       119  0:29:02  Janine Binder  David Boder
# 52870  48131        493       119  0:29:48  Janine Binder  David Boder
#
#                                            original_text  \
# a
# 4      Let me tell you frankly  : Do not tell me some...
# 6      … until today. But to you personally. Where di...
# 8      How old were you then? What grade were you in ...
# 10          What means “first grade”? The highest grade?
# 12                                    … of the “Volks-”?
# ...                                                  ...
# 52856              Was she Jewish, a Jewish girl friend?
# 52858           And she too was there as an Aryan woman?
# 52860                                     Found courage?
# 52862                                                So?
# 52870                             Who were they, French?
#
#                                                BrackInfo           IsKeep  \
# a
# 4      [('[', '?', ']'), ('[', 'possibly “we are info...  ['O', 'O', 'Y']
# 6           [('[', 'Bend down to the microphone?', ']')]            ['N']
# 8                                                     []               []
# 10                                                    []               []
# 12                                                    []               []
# ...                                                  ...              ...
# 52856                                                 []               []
# 52858                                                 []               []
# 52860                                                 []               []
# 52862                                                 []               []
# 52870                                                 []               []
#
#                                    Info  ...  is_question  is_command  \
# a                                        ...
# 4                                    []  ...         TRUE       FALSE
# 6      ['Bend down to the microphone?']  ...         TRUE       FALSE
# 8                                    []  ...         TRUE       FALSE
# 10                                   []  ...         TRUE       FALSE
# 12                                   []  ...         TRUE       FALSE
# ...                                 ...  ...          ...         ...
# 52856                                []  ...         TRUE       FALSE
# 52858                                []  ...         TRUE       FALSE
# 52860                                []  ...         TRUE       FALSE
# 52862                                []  ...         TRUE       FALSE
# 52870                                []  ...         TRUE       FALSE
#
#                                         chain_of_thought  \
# a
# 4      In the Question, the pronouns 'you' and 'your'...
# 6      In the provided Previous Context, the subject ...
# 8      In the provided context, the interviewee is Mr...
# 10     The Question contains the pronoun 'the highest...
# 12     The question contains the pronoun "the" which ...
# ...                                                  ...
# 52856  In the Previous Context, the interviewee menti...
# 52858  In the Question, the pronoun "she" likely refe...
# 52860  The question 'Found courage?' does not contain...
# 52862  The question 'So?' is too vague and does not c...
# 52870  In the Previous Context, the term 'they' in th...
#
#       contains_unresolved_pronoun enough_context_provided  \
# a
# 4                           FALSE                    TRUE
# 6                           FALSE                    TRUE
# 8                           FALSE                    TRUE
# 10                           TRUE                   FALSE
# 12                           TRUE                   FALSE
# ...                           ...                     ...
# 52856                        TRUE                   FALSE
# 52858                        TRUE                    TRUE
# 52860                       FALSE                    TRUE
# 52862                       FALSE                    TRUE
# 52870                        TRUE                    TRUE
#
#                                       disambiguated_text was_disambiguated  \
# a
# 4      Let me tell you frankly: Do not tell me some g...              TRUE
# 6      ... until today. But to you personally, Mr. Il...              TRUE
# 8      How old were you then? What grade were you in ...              TRUE
# 10                                                                   FALSE
# 12                                                                   FALSE
# ...                                                  ...               ...
# 52856                                                                FALSE
# 52858  And your girlfriend too was there as an Aryan ...              TRUE
# 52860                                                                FALSE
# 52862                                                                FALSE
# 52870                      Who were the French soldiers?              TRUE
#
#                                       text_for_rewriting decision    reason
# a
# 4      Let me tell you frankly: Do not tell me some g...    False  Too long
# 6      … until today. But to you personally. Where di...    False  Too long
# 8      How old were you then? What grade were you in ...      NaN       NaN
# 10          What means “first grade”? The highest grade?      NaN       NaN
# 12                                    … of the “Volks-”?      NaN       NaN
# ...                                                  ...      ...       ...
# 52856              Was she Jewish, a Jewish girl friend?      NaN       NaN
# 52858  And your girlfriend too was there as an Aryan ...      NaN       NaN
# 52860                                     Found courage?      NaN       NaN
# 52862                                                So?      NaN       NaN
# 52870                      Who were the French soldiers?      NaN       NaN
#
# [15808 rows x 26 columns]

# %%
input_df = disambiguated_df[disambiguated_df['decision'] != False]
input_df = pd.DataFrame(input_df['text_for_rewriting'])
input_df
# Out:
#                                       text_for_rewriting
# a
# 8      How old were you then? What grade were you in ...
# 10          What means “first grade”? The highest grade?
# 12                                    … of the “Volks-”?
# 14     Yes. The fourth grade of the “Mittelschule.” S...
# 16                  Yes. So, and in which city were you?
# ...                                                  ...
# 52856              Was she Jewish, a Jewish girl friend?
# 52858  And your girlfriend too was there as an Aryan ...
# 52860                                     Found courage?
# 52862                                                So?
# 52870                      Who were the French soldiers?
#
# [13224 rows x 1 columns]

# %% [markdown]
# ## Define Schema

# %%
from pydantic import BaseModel, Field
from typing import List, Literal

class ResponseFormat(BaseModel):
  decision: bool
  reason: str

input_prompt = "{text_for_rewriting}"

system_prompt = "Your job is to identify questions that are incomplete and need more context to be added to them. Your response should be true if the question needs to be rewritten and false if not. Justify your choice with reasoning. Your response should be in the format of decision. reason: "

# %% [markdown]
# ## Batch Processes

# %%
#@title Run Batch Process
from google.colab import userdata
import os

#set environment
os.environ['OPENAI_API_KEY'] = userdata.get('OPEN_AI_PROJECT_KEY')

# %%
# Initialize the processor
processor = BatchProcessor(api_key=os.getenv('OPENAI_API_KEY'), response_format=ResponseFormat, llm_model = "ft:gpt-4o-2024-08-06:ucla-cultural-heritage-ai-lab::B5h9mAHM")

#Create Batch Process Compatible Schema
schema = generate_schema(ResponseFormat)
processor.set_schema(schema)

# Define Data to Process
process_df = input_df

# Assemble Batch Processing File
processor.create_tasks(process_df, system_prompt, input_prompt)
processor.write_tasks_to_file(filename="batch_tasks_classification.jsonl")

# Upload tasks
file_id = processor.upload_file(filename="batch_tasks_classification.jsonl")

# Create batch job
processor.create_batch_job(file_id)
# Out:
# Batch created with ID: batch_67e780b6b9a08190878ba7ebc9a882a1
# 'batch_67e780b6b9a08190878ba7ebc9a882a1'

# %%
BATCH_ID = 'batch_67e780b6b9a08190878ba7ebc9a882a1' #replace with your batch_id

# %%
# Cancel batch job
#processor.cancel_batch(batch_id = BATCH_ID)

# %%
# Monitor progress
processor = BatchProcessor(api_key=os.getenv('OPENAI_API_KEY'), response_format=ResponseFormat)
processor.monitor_batch(batch_id = BATCH_ID)
# Out:
# Monitoring batch job...
# Batch job is still processing... Status: in_progress
# Batch job is still processing... Status: in_progress
# Batch job is still processing... Status: finalizing
# Batch job is still processing... Status: finalizing
# Batch job completed.
# Batch(id='batch_67e780b6b9a08190878ba7ebc9a882a1', completion_window='24h', created_at=1743225014, endpoint='/v1/chat/completions', input_file_id='file-YAEpt4aT83HSSsHofPmF5H', object='batch', status='completed', cancelled_at=None, cancelling_at=None, completed_at=1743228143, error_file_id=None, errors=None, expired_at=None, expires_at=1743311414, failed_at=None, finalizing_at=1743226999, in_progress_at=1743225018, metadata=None, output_file_id='file-EvHsnPAV5Li5acT3tmzs5T', request_counts=BatchRequestCounts(completed=13224, failed=0, total=13224))

# %%
# Download results from Batch ID
processor = BatchProcessor(api_key=os.getenv('OPENAI_API_KEY'),  response_format=ResponseFormat)
processor.download_results(output_filename='batch_results_classification.json', batch_id = BATCH_ID, overwrite=True)
# Out:
# Downloading file with ID: file-EvHsnPAV5Li5acT3tmzs5T
# Results downloaded to file: batch_results_classification.json

# %%
# Parse results
processor = BatchProcessor(api_key=os.getenv('OPENAI_API_KEY'), response_format=ResponseFormat)
results_df = processor.parse_results(filename='batch_results_classification.json')

# %%
results_df
# Out:
#        decision                                             reason  custom_id
# 0          True  The question lacks context regarding the speci...          8
# 1          True  The question lacks clarity regarding the conte...         10
# 2          True  The question lacks clarity on what specific as...         12
# 3          True  The question lacks clarity regarding the educa...         14
# 4          True  The question lacks clarity on the context of t...         16
# ...         ...                                                ...        ...
# 13219      True  The question lacks specificity about who 'she'...      52856
# 13220     False  The question is straightforward, asking about ...      52858
# 13221      True  The question lacks context regarding what spec...      52860
# 13222      True  The question 'So?' lacks context regarding wha...      52862
# 13223      True  The question lacks specificity regarding which...      52870
#
# [13224 rows x 3 columns]

# %%
# join results to original data frame on index
#df = df.reset_index() # You might need to reset index?
for index, row in results_df.iterrows():
  disambiguated_df.at[row['custom_id'], 'decision'] = row['decision']
  disambiguated_df.at[row['custom_id'], 'reason'] = row['reason']
disambiguated_df
# Out:
#        index  file_part  file_num     Time          Names      Speaker  \
# a
# 4      49911          4         1  0:01:54       Ilmar A.  David Boder
# 6      49913          6         1  0:02:38       Ilmar A.  David Boder
# 8      49915          8         1  0:03:19       Ilmar A.  David Boder
# 10     49917         10         1  0:03:31       Ilmar A.  David Boder
# 12     49919         12         1  0:03:38       Ilmar A.  David Boder
# ...      ...        ...       ...      ...            ...          ...
# 52856  48117        479       119  0:28:21  Janine Binder  David Boder
# 52858  48119        481       119  0:28:23  Janine Binder  David Boder
# 52860  48121        483       119  0:28:55  Janine Binder  David Boder
# 52862  48123        485       119  0:29:02  Janine Binder  David Boder
# 52870  48131        493       119  0:29:48  Janine Binder  David Boder
#
#                                            original_text  \
# a
# 4      Let me tell you frankly  : Do not tell me some...
# 6      … until today. But to you personally. Where di...
# 8      How old were you then? What grade were you in ...
# 10          What means “first grade”? The highest grade?
# 12                                    … of the “Volks-”?
# ...                                                  ...
# 52856              Was she Jewish, a Jewish girl friend?
# 52858           And she too was there as an Aryan woman?
# 52860                                     Found courage?
# 52862                                                So?
# 52870                             Who were they, French?
#
#                                                BrackInfo           IsKeep  \
# a
# 4      [('[', '?', ']'), ('[', 'possibly “we are info...  ['O', 'O', 'Y']
# 6           [('[', 'Bend down to the microphone?', ']')]            ['N']
# 8                                                     []               []
# 10                                                    []               []
# 12                                                    []               []
# ...                                                  ...              ...
# 52856                                                 []               []
# 52858                                                 []               []
# 52860                                                 []               []
# 52862                                                 []               []
# 52870                                                 []               []
#
#                                    Info  ...  is_question  is_command  \
# a                                        ...
# 4                                    []  ...         TRUE       FALSE
# 6      ['Bend down to the microphone?']  ...         TRUE       FALSE
# 8                                    []  ...         TRUE       FALSE
# 10                                   []  ...         TRUE       FALSE
# 12                                   []  ...         TRUE       FALSE
# ...                                 ...  ...          ...         ...
# 52856                                []  ...         TRUE       FALSE
# 52858                                []  ...         TRUE       FALSE
# 52860                                []  ...         TRUE       FALSE
# 52862                                []  ...         TRUE       FALSE
# 52870                                []  ...         TRUE       FALSE
#
#                                         chain_of_thought  \
# a
# 4      In the Question, the pronouns 'you' and 'your'...
# 6      In the provided Previous Context, the subject ...
# 8      In the provided context, the interviewee is Mr...
# 10     The Question contains the pronoun 'the highest...
# 12     The question contains the pronoun "the" which ...
# ...                                                  ...
# 52856  In the Previous Context, the interviewee menti...
# 52858  In the Question, the pronoun "she" likely refe...
# 52860  The question 'Found courage?' does not contain...
# 52862  The question 'So?' is too vague and does not c...
# 52870  In the Previous Context, the term 'they' in th...
#
#       contains_unresolved_pronoun enough_context_provided  \
# a
# 4                           FALSE                    TRUE
# 6                           FALSE                    TRUE
# 8                           FALSE                    TRUE
# 10                           TRUE                   FALSE
# 12                           TRUE                   FALSE
# ...                           ...                     ...
# 52856                        TRUE                   FALSE
# 52858                        TRUE                    TRUE
# 52860                       FALSE                    TRUE
# 52862                       FALSE                    TRUE
# 52870                        TRUE                    TRUE
#
#                                       disambiguated_text was_disambiguated  \
# a
# 4      Let me tell you frankly: Do not tell me some g...              TRUE
# 6      ... until today. But to you personally, Mr. Il...              TRUE
# 8      How old were you then? What grade were you in ...              TRUE
# 10                                                                   FALSE
# 12                                                                   FALSE
# ...                                                  ...               ...
# 52856                                                                FALSE
# 52858  And your girlfriend too was there as an Aryan ...              TRUE
# 52860                                                                FALSE
# 52862                                                                FALSE
# 52870                      Who were the French soldiers?              TRUE
#
#                                       text_for_rewriting decision  \
# a
# 4      Let me tell you frankly: Do not tell me some g...    False
# 6      … until today. But to you personally. Where di...    False
# 8      How old were you then? What grade were you in ...     True
# 10          What means “first grade”? The highest grade?     True
# 12                                    … of the “Volks-”?     True
# ...                                                  ...      ...
# 52856              Was she Jewish, a Jewish girl friend?     True
# 52858  And your girlfriend too was there as an Aryan ...    False
# 52860                                     Found courage?     True
# 52862                                                So?     True
# 52870                      Who were the French soldiers?     True
#
#                                                   reason
# a
# 4                                               Too long
# 6                                               Too long
# 8      The question lacks context regarding the speci...
# 10     The question lacks clarity regarding the conte...
# 12     The question lacks clarity on what specific as...
# ...                                                  ...
# 52856  The question lacks specificity about who 'she'...
# 52858  The question is straightforward, asking about ...
# 52860  The question lacks context regarding what spec...
# 52862  The question 'So?' lacks context regarding wha...
# 52870  The question lacks specificity regarding which...
#
# [15808 rows x 26 columns]

# %%
processed_df = disambiguated_df.fillna('')
processed_df.to_csv("classified_results.csv")

from google.colab import files
files.download("classified_results.csv")
# Out:
# <ipython-input-21-eb7032208118>:1: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   processed_df = disambiguated_df.fillna('')

# %% [markdown]
# # Part 3: Context Rewriting

# %% [markdown]
# ## Import Data

# %%
sheet_id = "17oL-BD7dERURpVE4yKKo7a0mormQ9SRXvQ3hQP9Iek8"
worksheet_name = "Sheet1"
sh = gc.open_by_key(sheet_id)
worksheet = sh.worksheet(worksheet_name)
processed_df = pd.DataFrame(worksheet.get_all_records())

# %%
import pandas as pd
#processed_df = processed_df.set_index('a', drop = True)
processed_df = pd.read_csv('classified_results_boderb.csv')
processed_df = processed_df.set_index('a', drop = True)
processed_df.head()
# Out:
#     index  file_part  file_num     Time     Names      Speaker  \
# a
# 4   49911          4         1  0:01:54  Ilmar A.  David Boder
# 6   49913          6         1  0:02:38  Ilmar A.  David Boder
# 8   49915          8         1  0:03:19  Ilmar A.  David Boder
# 10  49917         10         1  0:03:31  Ilmar A.  David Boder
# 12  49919         12         1  0:03:38  Ilmar A.  David Boder
#
#                                         original_text  \
# a
# 4   Let me tell you frankly  : Do not tell me some...
# 6   … until today. But to you personally. Where di...
# 8   How old were you then? What grade were you in ...
# 10       What means “first grade”? The highest grade?
# 12                                 … of the “Volks-”?
#
#                                             BrackInfo           IsKeep  \
# a
# 4   [('[', '?', ']'), ('[', 'possibly “we are info...  ['O', 'O', 'Y']
# 6        [('[', 'Bend down to the microphone?', ']')]            ['N']
# 8                                                  []               []
# 10                                                 []               []
# 12                                                 []               []
#
#                                 Info  ...  is_question  is_command  \
# a                                     ...
# 4                                 []  ...         True       False
# 6   ['Bend down to the microphone?']  ...         True       False
# 8                                 []  ...         True       False
# 10                                []  ...         True       False
# 12                                []  ...         True       False
#
#                                      chain_of_thought  \
# a
# 4   In the Question, the pronouns 'you' and 'your'...
# 6   In the provided Previous Context, the subject ...
# 8   In the provided context, the interviewee is Mr...
# 10  The Question contains the pronoun 'the highest...
# 12  The question contains the pronoun "the" which ...
#
#    contains_unresolved_pronoun enough_context_provided  \
# a
# 4                        False                    True
# 6                        False                    True
# 8                        False                    True
# 10                        True                   False
# 12                        True                   False
#
#                                    disambiguated_text  was_disambiguated  \
# a
# 4   Let me tell you frankly: Do not tell me some g...               True
# 6   ... until today. But to you personally, Mr. Il...               True
# 8   How old were you then? What grade were you in ...               True
# 10                                                NaN              False
# 12                                                NaN              False
#
#                                    text_for_rewriting decision  \
# a
# 4   Let me tell you frankly: Do not tell me some g...    False
# 6   … until today. But to you personally. Where di...    False
# 8   How old were you then? What grade were you in ...     True
# 10       What means “first grade”? The highest grade?     True
# 12                                 … of the “Volks-”?     True
#
#                                                reason
# a
# 4                                            Too long
# 6                                            Too long
# 8   The question lacks context regarding the speci...
# 10  The question lacks clarity regarding the conte...
# 12  The question lacks clarity on what specific as...
#
# [5 rows x 26 columns]

# %%
input_df = processed_df[processed_df['decision'] == True]
input_df = pd.DataFrame(input_df[['text_for_rewriting', 'context', 'reason']])
input_df.head()
# Out:
#                                    text_for_rewriting  \
# a
# 8   How old were you then? What grade were you in ...
# 10       What means “first grade”? The highest grade?
# 12                                 … of the “Volks-”?
# 14  Yes. The fourth grade of the “Mittelschule.” S...
# 16               Yes. So, and in which city were you?
#
#                                               context  \
# a
# 8   INTERVIEWER:  Spool 152A, Spool 152A. Ilmar A....
# 10  INTERVIEWER:  Spool 152A, Spool 152A. Ilmar A....
# 12  INTERVIEWER:  Spool 152A, Spool 152A. Ilmar A....
# 14  INTERVIEWER:  Spool 152A, Spool 152A. Ilmar A....
# 16  INTERVIEWER: Munich, September the 24th, 1946,...
#
#                                                reason
# a
# 8   The question lacks context regarding the speci...
# 10  The question lacks clarity regarding the conte...
# 12  The question lacks clarity on what specific as...
# 14  The question lacks clarity regarding the educa...
# 16  The question lacks clarity on the context of t...

# %% [markdown]
# ## Define Schema

# %%
# Define Schema and Prompt

from pydantic import BaseModel, Field
from typing import List, Literal


system_prompt = "Your role is to process data factually without generating hallucinations or fabrications"

class ResponseFormat(BaseModel):
    step_by_step_reasoning: str = Field(..., description="Step-by-step reasoning behind the response.")
    sufficient_context_provided: bool = Field(..., description="True if there is sufficient Previous Context to add correct information to the Question. You should be absolutely certain with your interpretation of the text; False if more Previous Context is needed.")
    question_with_clarified_context: str = Field(..., description="If there is enough Previous Context to clarify the question in the Question, revise the Question with as little added text as possible while still adding the neccessary context. Maintain the original langauge and tone of the historical material as closely as possible.. Only return the updated text, nothing else. Otherwise, respond with an empty string")



input_prompt = """Task:
The following text is from an interview.
Your task is to clarify generic and incomplete questions in the Question based on the Previous Context and the Reason for Rewriting.
When rewriting the current text, be as simple as possible. Add just enough context so that someone familiar with the interview can follow along, but do not add unneccessary details or phrases that just add words.
Determine if there is enough Previous Context to add correct context to the Current Text. If you are not certain of the meaning of the Question based on the Previous Context, there is not enough previous context to add context to the Question.
If there is enough Previous Context to clarify the question in the Question, revise the Question with as little added text as possible while still adding the neccessary context. Maintain the original langauge and tone of the historical material as closely as possible.
If not, respond with an empty string.


Previous Context: {context}

Question: {text_for_rewriting}

Reason for Rewriting: {reason}
"""

# %% [markdown]
# ## Run Batch Processes

# %%
#@title Run Batch Process
from google.colab import userdata
import os

#set environment
os.environ['OPENAI_API_KEY'] = userdata.get('OPEN_AI_PROJECT_KEY')

# %%
# Initialize the processor
processor = BatchProcessor(api_key=os.getenv('OPENAI_API_KEY'), response_format=ResponseFormat)

#Create Batch Process Compatible Schema
schema = generate_schema(ResponseFormat)
processor.set_schema(schema)

# Define Data to Process
process_df = input_df

# Assemble Batch Processing File
processor.create_tasks(process_df, system_prompt, input_prompt)
processor.write_tasks_to_file(filename="batch_tasks.jsonl")

# Upload tasks
file_id = processor.upload_file(filename="batch_tasks.jsonl")

# Create batch job
processor.create_batch_job(file_id)
# Out:
# Batch created with ID: batch_67e7a2b343648190bf95b2ae63788d34
# 'batch_67e7a2b343648190bf95b2ae63788d34'

# %%
BATCH_ID = 'batch_67e7a2b343648190bf95b2ae63788d34' #replace with your batch_id

# %%
# Cancel batch job
#processor.cancel_batch(batch_id = BATCH_ID)

# %%
# Monitor progress
processor = BatchProcessor(api_key=os.getenv('OPENAI_API_KEY'), response_format=ResponseFormat)
processor.monitor_batch(batch_id = BATCH_ID)
# Out:
# Monitoring batch job...
# Batch job completed.
# Batch(id='batch_67e7a2b343648190bf95b2ae63788d34', completion_window='24h', created_at=1743233715, endpoint='/v1/chat/completions', input_file_id='file-6C2t6z4rMqedNyzyVcr8es', object='batch', status='completed', cancelled_at=None, cancelling_at=None, completed_at=1743236508, error_file_id=None, errors=None, expired_at=None, expires_at=1743320115, failed_at=None, finalizing_at=1743235701, in_progress_at=1743233718, metadata=None, output_file_id='file-BLqFCufhHaSQJEgyQ3G8NN', request_counts=BatchRequestCounts(completed=11430, failed=0, total=11430))

# %%
# Download results from Batch ID
processor = BatchProcessor(api_key=os.getenv('OPENAI_API_KEY'),  response_format=ResponseFormat)
processor.download_results(output_filename='batch_results_classification.json', batch_id = BATCH_ID, overwrite=True)
# Out:
# Downloading file with ID: file-BLqFCufhHaSQJEgyQ3G8NN
# Results downloaded to file: batch_results_classification.json

# %%
# Parse results
processor = BatchProcessor(api_key=os.getenv('OPENAI_API_KEY'), response_format=ResponseFormat)
results_df = processor.parse_results(filename='batch_results_classification.json')
results_df
# Out:
# Error parsing result with model ResponseFormat: 1 validation error for ResponseFormat
#   Invalid JSON: expected `,` or `}` at line 1 column 552 [type=json_invalid, input_value='{"step_by_step_reasoning...er basic necessities?"}', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.10/v/json_invalid
# Raw content: {"step_by_step_reasoning":"1. The original question uses the term 'commodity' which is vague without context. 2. The Previous Context indicates that the Subject mentioned a lack of basic needs and facilities after arriving in Birkenau, implying that 'commodity' refers to essential facilities. 3. The rewritten question needs to clarify that the interviewer is specifically asking about toilet facilities in relation to the absence of other necessities mentioned by the Subject.","sufficient_context_provided":true,"question_with_clarified_context":""Commodity," you mean no toilet facilities and other basic necessities?"}
# Error parsing result with model ResponseFormat: 1 validation error for ResponseFormat
#   Invalid JSON: expected `,` or `}` at line 1 column 68 [type=json_invalid, input_value='{"step_by_step_reasoning...during the grillings?"}', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.10/v/json_invalid
# Raw content: {"step_by_step_reasoning":"1. The original question 'How did they "hang up"?' is vague because it doesn't specify who 'they' refers to or the context of the hanging up. 2. The previous context discusses the subject's experiences during an interrogation, specifically mentioning being 'hung up' three times during grillings in Limoges. 3. To clarify the question, it's important to reference the grillings and specify that the subject refers to the individuals conducting the interrogations. 4. The revised question should maintain the original tone while providing necessary context about the interrogators and the situation of the hangings.","sufficient_context_provided":true,"question_with_clarified_context":"How did the interrogators 'hang you up' during the grillings?"}
# Error parsing result with model ResponseFormat: 1 validation error for ResponseFormat
#   Invalid JSON: expected `,` or `}` at line 1 column 593 [type=json_invalid, input_value='{"step_by_step_reasoning...nment at the factory?"}', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.10/v/json_invalid
# Raw content: {"step_by_step_reasoning":"1. The question asks about the meaning of the phrase \"in the square.\" 2. The Previous Context does not explain what the \"square\" refers to specifically. 3. However, it is implied that the 'square' is related to the conditions or organization of the work environment in the factory where the Subject worked. 4. To clarify this without adding unnecessary details, I will provide just enough context to indicate that this phrase is connected to the Subject's work setting.","sufficient_context_provided":true,"question_with_clarified_context":"What does it mean, "in the square" in reference to the work environment at the factory?"}
# Error parsing result with model ResponseFormat: 1 validation error for ResponseFormat
#   Invalid JSON: expected `,` or `}` at line 1 column 53 [type=json_invalid, input_value='{"step_by_step_reasoning..._clarified_context":""}', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.10/v/json_invalid
# Raw content: {"step_by_step_reasoning":"1. The question 'And by "The Red Cross"?' is vague and does not specify what aspect of the Red Cross is being referred to. 2. The context provided does not mention the Red Cross at all, creating ambiguity in the question. 3. Since there is no mention of the Red Cross in the previous context, it's unclear what the subject might respond to regarding the Red Cross. 4. Therefore, without additional context, I cannot clarify the question meaningfully.","sufficient_context_provided":false,"question_with_clarified_context":""}
# Error parsing result with model ResponseFormat: 1 validation error for ResponseFormat
#   Invalid JSON: expected `,` or `}` at line 1 column 615 [type=json_invalid, input_value='{"step_by_step_reasoning...ocation in the lager?"}', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.10/v/json_invalid
# Raw content: {"step_by_step_reasoning":"1. The original question asks about the meaning of \"work slips,\" which is a term used in the context of the lager but is not explained. 2. The previous context provides information about the daily routine and organization of labor in the lager, indicating that work slips are related to the allocation of work to individuals based on their assigned firms. 3. To clarify the question, I need to relate the term \"work slips\" directly to its function in the context of the lager's labor system.","sufficient_context_provided":true,"question_with_clarified_context":"What does it mean, "work slips" in the context of labor allocation in the lager?"}
# Error parsing result with model ResponseFormat: 1 validation error for ResponseFormat
#   Invalid JSON: expected `,` or `}` at line 1 column 70 [type=json_invalid, input_value='{"step_by_step_reasoning...out the deportations?"}', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.10/v/json_invalid
# Raw content: {"step_by_step_reasoning":"The original question 'And who are these "ours"?', lacks clarity because it does not specify what group or individuals the term 'ours' refers to. In the context of the interview, 'ours' likely refers to the community or group of Jews that the subject is discussing, particularly in relation to those who were being warned about the deportations. The revision adds the necessary context to clarify who 'ours' is in relation to the deportation warning, making it clear that it pertains to the Jewish community.","sufficient_context_provided":true,"question_with_clarified_context":"And who are these \"ours\" that you warned about the deportations?"}
# Error parsing result with model ResponseFormat: 1 validation error for ResponseFormat
#   Invalid JSON: expected `,` or `}` at line 1 column 763 [type=json_invalid, input_value='{"step_by_step_reasoning...eek a different path?"}', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.10/v/json_invalid
# Raw content: {"step_by_step_reasoning":"1. The original question is vague because it does not specify which uncle is being referred to or the context of the situation he was in. 2. The Previous Context mentions the uncle's age and his predicament concerning his fate and the fate of his family members. 3. The uncle is in a difficult situation regarding whether to make a decision based on logic ('his mind') or emotion ('his heart'). 4. Therefore, I can clarify the question by adding context about the uncle's situation and the decision he was facing. 5. The revised question retains the original's intent while providing the necessary context to understand it better.","sufficient_context_provided":true,"question_with_clarified_context":"What did your uncle mean by — "follow his mind" regarding his decision about whether to stay with his family at the camp or seek a different path?"}
# Error parsing result with model ResponseFormat: 1 validation error for ResponseFormat
#   Invalid JSON: expected `,` or `}` at line 1 column 424 [type=json_invalid, input_value='{"step_by_step_reasoning... Germans to Nice…" "}', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.10/v/json_invalid
# Raw content: {"step_by_step_reasoning":"The original question is vague and does not specify what is meant by 'there' or the nature of the 'mass escape.' By referencing the context of the interview where the subject discusses a mass escape from the Germans to Nice, I have clarified the question to ensure it relates directly to that specific event.","sufficient_context_provided":true,"question_with_clarified_context":"Let's correct: "There where there is a mass escape from Germans to Nice…" "}
# Error parsing result with model ResponseFormat: 1 validation error for ResponseFormat
#   Invalid JSON: expected `,` or `}` at line 1 column 59 [type=json_invalid, input_value='{"step_by_step_reasoning...s, what did you mean?"}', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.10/v/json_invalid
# Raw content: {"step_by_step_reasoning":"1. The original question 'So. "Run away from there yourself"? ' does not specify who the speaker is or the context of the statement. 2. The Previous Context indicates that the subject, Ms. Fira Monk, is discussing Rabbi Schmierson's efforts to evacuate Jews from Voiron to Nice during the war. 3. To clarify, I need to reference Ms. Monk's perspective on the situation and her advice regarding mass escape. 4. The revised question will include these details to make it clear that it is about her advice during a mass escape situation.","sufficient_context_provided":true,"question_with_clarified_context":"So, Ms. Monk, when you said, \"Run away from there yourself\" in the context of the mass escape from Germans, what did you mean?"}
# Error parsing result with model ResponseFormat: 1 validation error for ResponseFormat
#   Invalid JSON: expected `,` or `}` at line 1 column 65 [type=json_invalid, input_value='{"step_by_step_reasoning...oyed like the others?"}', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.10/v/json_invalid
# Raw content: {"step_by_step_reasoning":"1. The original question 'The whole "synagogue yard"?' is vague and does not specify what the interviewer wants to know about the synagogue yard. 2. The previous context discusses the Choral Synagogue and its state, implying a connection to the synagogue yard. 3. To clarify the question, I need to specify whether the interviewer is asking about the condition, history, or any specific events related to the synagogue yard. 4. Since the context suggests a discussion about its status, I will rewrite the question to focus on whether the synagogue yard still exists or has been affected, in line with the conversation about destruction.","sufficient_context_provided":true,"question_with_clarified_context":"What happened to the whole "synagogue yard"? Is it still intact or has it been destroyed like the others?"}
# Error parsing result with model ResponseFormat: 1 validation error for ResponseFormat
#   Invalid JSON: expected `,` or `}` at line 1 column 620 [type=json_invalid, input_value='{"step_by_step_reasoning...\'s General District?"}', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.10/v/json_invalid
# Raw content: {"step_by_step_reasoning":"1. The question \"What does it mean 'on the black'?\" is vague as it doesn't specify the context of 'on the black' in relation to the previous discussion of the labor camp and fleeing. 2. The term 'on the black' could refer to various meanings, but in this context, it likely relates to the illegal or under-the-table way they arrived in the Governor's General District. 3. To clarify the question, it is essential to add context about the interviewee's situation and the implications of their escape.","sufficient_context_provided":true,"question_with_clarified_context":"What does it mean "on the black" in the context of your escape to the Governor's General District?"}
# Error parsing result with model ResponseFormat: 1 validation error for ResponseFormat
#   Invalid JSON: expected `,` or `}` at line 1 column 764 [type=json_invalid, input_value='{"step_by_step_reasoning...of German occupation?"}', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.10/v/json_invalid
# Raw content: {"step_by_step_reasoning":"1. The original question asks why the 'Governor General's district' is referred to in a specific way without providing context on what it is. 2. The previous context indicates that the subject is discussing their experiences during the German occupation, and the 'Governor General's district' likely refers to the administrative region under German control. 3. To clarify, I need to connect the term 'Governor General's district' with the context of the German occupation and administrative divisions. 4. I will revise the question to include this context succinctly, ensuring it remains relevant to the interview's historical context.","sufficient_context_provided":true,"question_with_clarified_context":"Yes. Why do you call it the "Governor General's district" in the context of German occupation?"}
# Error parsing result with model ResponseFormat: 1 validation error for ResponseFormat
#   Invalid JSON: expected `,` or `}` at line 1 column 260 [type=json_invalid, input_value='{"step_by_step_reasoning...o the Jews of Warsaw?"}', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.10/v/json_invalid
# Raw content: {"step_by_step_reasoning":"1. The original question asks about the meaning of 'smelt' but does not specify its context in the interview. 2. The Previous Context includes a mention of Polish friends advising the SUBJECT that 'the Jews of Warsaw go all to the "smelt."' 3. To clarify the question, I need to reference this context to ensure the respondent understands what 'smelt' is referring to in relation to the Jews of Warsaw. 4. I will add minimal necessary context to the question to maintain its simplicity while providing clarity.","sufficient_context_provided":true,"question_with_clarified_context":"What does that mean, to the "smelt," referring to what happened to the Jews of Warsaw?"}
#                                   step_by_step_reasoning  \
# 0      1. The Previous Context discusses Mr. Ilmar's ...
# 1      1. The original question asks for clarificatio...
# 2      1. The original question is incomplete and unc...
# 3      The question was unclear because it used speci...
# 4      The original question asks for the city but do...
# ...                                                  ...
# 11412  1. The original question 'Now tell me, how wer...
# 11413  1. The question refers to 'she' without specif...
# 11414  The original question 'Found courage?' is vagu...
# 11415  1. The previous context discusses the subject'...
# 11416  1. The original question is very generic and d...
#
#        sufficient_context_provided  \
# 0                             True
# 1                             True
# 2                             True
# 3                             True
# 4                             True
# ...                            ...
# 11412                         True
# 11413                         True
# 11414                         True
# 11415                         True
# 11416                         True
#
#                          question_with_clarified_context  custom_id
# 0      How old were you in 1940 when the Soviets came...          8
# 1      What does 'first grade' mean in the context of...         10
# 2      What did you learn about the concept of 'Volks...         12
# 3      Yes. The fourth grade of the 'Mittelschule.' S...         14
# 4      Yes. So, and in which city were you living whe...         16
# ...                                                  ...        ...
# 11412  Now tell me, how were you liberated in Stuttgart?      52852
# 11413  Was your girlfriend, who was deported with you...      52856
# 11414  Did you find courage during your imprisonment ...      52860
# 11415   So, what happened next after you were liberated?      52862
# 11416  Who were the French soldiers mentioned during ...      52870
#
# [11417 rows x 4 columns]

# %%
# join results to original data frame on index
#df = df.reset_index() # You might need to reset index?
context_df = processed_df.join(results_df.set_index('custom_id'), how='left')
context_df
# Out:
#        index  file_part  file_num     Time          Names      Speaker  \
# a
# 4      49911          4         1  0:01:54       Ilmar A.  David Boder
# 6      49913          6         1  0:02:38       Ilmar A.  David Boder
# 8      49915          8         1  0:03:19       Ilmar A.  David Boder
# 10     49917         10         1  0:03:31       Ilmar A.  David Boder
# 12     49919         12         1  0:03:38       Ilmar A.  David Boder
# ...      ...        ...       ...      ...            ...          ...
# 52856  48117        479       119  0:28:21  Janine Binder  David Boder
# 52858  48119        481       119  0:28:23  Janine Binder  David Boder
# 52860  48121        483       119  0:28:55  Janine Binder  David Boder
# 52862  48123        485       119  0:29:02  Janine Binder  David Boder
# 52870  48131        493       119  0:29:48  Janine Binder  David Boder
#
#                                            original_text  \
# a
# 4      Let me tell you frankly  : Do not tell me some...
# 6      … until today. But to you personally. Where di...
# 8      How old were you then? What grade were you in ...
# 10          What means “first grade”? The highest grade?
# 12                                    … of the “Volks-”?
# ...                                                  ...
# 52856              Was she Jewish, a Jewish girl friend?
# 52858           And she too was there as an Aryan woman?
# 52860                                     Found courage?
# 52862                                                So?
# 52870                             Who were they, French?
#
#                                                BrackInfo           IsKeep  \
# a
# 4      [('[', '?', ']'), ('[', 'possibly “we are info...  ['O', 'O', 'Y']
# 6           [('[', 'Bend down to the microphone?', ']')]            ['N']
# 8                                                     []               []
# 10                                                    []               []
# 12                                                    []               []
# ...                                                  ...              ...
# 52856                                                 []               []
# 52858                                                 []               []
# 52860                                                 []               []
# 52862                                                 []               []
# 52870                                                 []               []
#
#                                    Info  ...  contains_unresolved_pronoun  \
# a                                        ...
# 4                                    []  ...                        False
# 6      ['Bend down to the microphone?']  ...                        False
# 8                                    []  ...                        False
# 10                                   []  ...                         True
# 12                                   []  ...                         True
# ...                                 ...  ...                          ...
# 52856                                []  ...                         True
# 52858                                []  ...                         True
# 52860                                []  ...                        False
# 52862                                []  ...                        False
# 52870                                []  ...                         True
#
#        enough_context_provided  \
# a
# 4                         True
# 6                         True
# 8                         True
# 10                       False
# 12                       False
# ...                        ...
# 52856                    False
# 52858                     True
# 52860                     True
# 52862                     True
# 52870                     True
#
#                                       disambiguated_text was_disambiguated  \
# a
# 4      Let me tell you frankly: Do not tell me some g...              True
# 6      ... until today. But to you personally, Mr. Il...              True
# 8      How old were you then? What grade were you in ...              True
# 10                                                   NaN             False
# 12                                                   NaN             False
# ...                                                  ...               ...
# 52856                                                NaN             False
# 52858  And your girlfriend too was there as an Aryan ...              True
# 52860                                                NaN             False
# 52862                                                NaN             False
# 52870                      Who were the French soldiers?              True
#
#                                       text_for_rewriting  decision  \
# a
# 4      Let me tell you frankly: Do not tell me some g...     False
# 6      … until today. But to you personally. Where di...     False
# 8      How old were you then? What grade were you in ...      True
# 10          What means “first grade”? The highest grade?      True
# 12                                    … of the “Volks-”?      True
# ...                                                  ...       ...
# 52856              Was she Jewish, a Jewish girl friend?      True
# 52858  And your girlfriend too was there as an Aryan ...     False
# 52860                                     Found courage?      True
# 52862                                                So?      True
# 52870                      Who were the French soldiers?      True
#
#                                                   reason  \
# a
# 4                                               Too long
# 6                                               Too long
# 8      The question lacks context regarding the speci...
# 10     The question lacks clarity regarding the conte...
# 12     The question lacks clarity on what specific as...
# ...                                                  ...
# 52856  The question lacks specificity about who 'she'...
# 52858  The question is straightforward, asking about ...
# 52860  The question lacks context regarding what spec...
# 52862  The question 'So?' lacks context regarding wha...
# 52870  The question lacks specificity regarding which...
#
#                                   step_by_step_reasoning  \
# a
# 4                                                    NaN
# 6                                                    NaN
# 8      1. The Previous Context discusses Mr. Ilmar's ...
# 10     1. The original question asks for clarificatio...
# 12     1. The original question is incomplete and unc...
# ...                                                  ...
# 52856  1. The question refers to 'she' without specif...
# 52858                                                NaN
# 52860  The original question 'Found courage?' is vagu...
# 52862  1. The previous context discusses the subject'...
# 52870  1. The original question is very generic and d...
#
#       sufficient_context_provided  \
# a
# 4                             NaN
# 6                             NaN
# 8                            True
# 10                           True
# 12                           True
# ...                           ...
# 52856                        True
# 52858                         NaN
# 52860                        True
# 52862                        True
# 52870                        True
#
#                          question_with_clarified_context
# a
# 4                                                    NaN
# 6                                                    NaN
# 8      How old were you in 1940 when the Soviets came...
# 10     What does 'first grade' mean in the context of...
# 12     What did you learn about the concept of 'Volks...
# ...                                                  ...
# 52856  Was your girlfriend, who was deported with you...
# 52858                                                NaN
# 52860  Did you find courage during your imprisonment ...
# 52862   So, what happened next after you were liberated?
# 52870  Who were the French soldiers mentioned during ...
#
# [15808 rows x 29 columns]

# %%
context_df = context_df.fillna('')

# %%
context_df.to_csv("rewritten_results.csv")

from google.colab import files
files.download("rewritten_results.csv")

# %% [markdown]
# ## Generate Stats and Flag Questions

# %%
#@title import data
#context_df = pd.read_csv("final_results.csv")

# %%
import re

def remove_special_entries(lst):
    return [s for s in lst if not re.fullmatch(r'[^a-zA-Z0-9]+', s)]

def contains_only_numbers(word_list):
    for word in word_list:
        if word.isdigit():  # Checks if the word consists only of digits
            return True
    return False

# %%
def process_row(row):

  context_added = False
  text = ""
  if row['question_with_clarified_context'] != "":
    text = row['question_with_clarified_context']
    context_added = True
  else:
    text = row['text_for_rewriting']

  if "Interviewer:" in text:
    text = text.replace("Interviewer:", "")
  if "Interviewee:" in text:
    text = text.replace("Interviewee:", "")
  if "INTERVIEWER:" in text:
    text = text.replace("INTERVIEWER:", "")

  text_tokenized = tokenize(row['text'])
  final_tokenized = tokenize(text)
  text_tokenized = remove_special_entries(text_tokenized)
  final_tokenized = remove_special_entries(final_tokenized)

  removed_words = set(text_tokenized) - set(final_tokenized)
  added_words = set(final_tokenized) - set(text_tokenized)

  added_length = len(added_words)
  removed_length = len(removed_words)

  text_length = len(text_tokenized)
  final_length = len(final_tokenized)

  #Flag Questions

  is_flagged = False

  flagged_words = ['yes', 'nu', 'experience', 'considering', 'especially', 'given', 'particularly', 'relation', 'regarding', 'circumstances', 'suggesting', 'mentioned']

  flag_reasoning = ""

  added_words = [word.lower() for word in added_words]
  removed_words = [word.lower() for word in removed_words]

  for word in added_words:
    if word in flagged_words:
      is_flagged = True
      flag_reasoning = flag_reasoning + " " + word
      break

  if (text_length <= 1) and (added_length >= 10):
    is_flagged = True
    flag_reasoning = flag_reasoning + " " + "One word elaboration"

  if (added_length >= 15):
    is_flagged = True
    flag_reasoning = flag_reasoning + " " + "Added " + str(added_length) + " words"

  if '[' in text:
    is_flagged = True
    flag_reasoning = flag_reasoning + " " + "has closing bracket"

  if ']' in text:
    is_flagged = True
    flag_reasoning = flag_reasoning + " " + "has opening bracket"

  if contains_only_numbers(added_words):
    is_flagged = True
    flag_reasoning = flag_reasoning + " " + "contains only numbers"

  flag_dict = {
      'context_added': context_added,
      'final_text': text,
      'tokenized_text': text_tokenized,
      'tokenized_final_text': final_tokenized,
      'added_words': added_words,
      'removed_words': removed_words,
      'added_length': added_length,
      'removed_length': removed_length,
      'final_length': final_length,
      'is_flagged': is_flagged,
      'flag_reasoning': flag_reasoning
  }

  return flag_dict

# %%
from tqdm import tqdm

def process_dataframe(df):
    """
    Function to process the entire dataframe using the process_row function and add results to the DataFrame.
    """
    results = []
    index = 1
    final = len(df)
    # Use tqdm to create a progress bar
    pbar = tqdm(df.iterrows())
    for idx, row in pbar:
        response_dict = process_row(row)

        # Append the response dict to the previous results
        results.append(response_dict)
        pbar.set_description(f"Processing row {index} of {final}")
        index += 1


    # Create a DataFrame from the results
    results_df = pd.DataFrame(results, index=df.index)

    # Merge results_df with the original df based on the index
    df = df.join(results_df, how='left')

    return df

# %%
final_df = process_dataframe(context_df)
# Out:
# Processing row 15808 of 15808: : 15808it [05:07, 51.35it/s]

# %%
final_df.to_csv("final_results.csv")

from google.colab import files
files.download("final_results.csv")

# %% [markdown]
# # Processsing Flagged Questions

# %%
# Run if you did the first part in a separate runtime

sheet_id = "1fXmcPPn7j5kg4ALdE5P2ZPgfaC_UpceuO9eDqWb_dP8" #Version A/B Results
worksheet_name = "Results Before Manual Revision"
sh = gc.open_by_key(sheet_id)
worksheet = sh.worksheet(worksheet_name)
final_df = pd.DataFrame(worksheet.get_all_records())
final_df = final_df.set_index('a', drop = True)
final_df
# Out:
#        index  file_part  file_num     Time          Names      Speaker  \
# a
# 4      49911          4         1  0:01:54       Ilmar A.  David Boder
# 6      49913          6         1  0:02:38       Ilmar A.  David Boder
# 8      49915          8         1  0:03:19       Ilmar A.  David Boder
# 10     49917         10         1  0:03:31       Ilmar A.  David Boder
# 12     49919         12         1  0:03:38       Ilmar A.  David Boder
# ...      ...        ...       ...      ...            ...          ...
# 52856  48117        479       119  0:28:21  Janine Binder  David Boder
# 52858  48119        481       119  0:28:23  Janine Binder  David Boder
# 52860  48121        483       119  0:28:55  Janine Binder  David Boder
# 52862  48123        485       119  0:29:02  Janine Binder  David Boder
# 52870  48131        493       119  0:29:48  Janine Binder  David Boder
#
#                                            original_text  \
# a
# 4      Let me tell you frankly  : Do not tell me some...
# 6      … until today. But to you personally. Where di...
# 8      How old were you then? What grade were you in ...
# 10          What means “first grade”? The highest grade?
# 12                                    … of the “Volks-”?
# ...                                                  ...
# 52856              Was she Jewish, a Jewish girl friend?
# 52858           And she too was there as an Aryan woman?
# 52860                                     Found courage?
# 52862                                                So?
# 52870                             Who were they, French?
#
#                                                BrackInfo           IsKeep  \
# a
# 4      [('[', '?', ']'), ('[', 'possibly “we are info...  ['O', 'O', 'Y']
# 6           [('[', 'Bend down to the microphone?', ']')]            ['N']
# 8                                                     []               []
# 10                                                    []               []
# 12                                                    []               []
# ...                                                  ...              ...
# 52856                                                 []               []
# 52858                                                 []               []
# 52860                                                 []               []
# 52862                                                 []               []
# 52870                                                 []               []
#
#                                    Info  ...  \
# a                                        ...
# 4                                    []  ...
# 6      ['Bend down to the microphone?']  ...
# 8                                    []  ...
# 10                                   []  ...
# 12                                   []  ...
# ...                                 ...  ...
# 52856                                []  ...
# 52858                                []  ...
# 52860                                []  ...
# 52862                                []  ...
# 52870                                []  ...
#
#                                     tokenized_final_text  \
# a
# 4      ['Let', 'me', 'tell', 'you', 'frankly', 'Do', ...
# 6      ['until', 'today', 'But', 'to', 'you', 'person...
# 8      ['How', 'old', 'were', 'you', 'in', '1940', 'w...
# 10     ['What', 'does', 'first', 'grade', 'mean', 'in...
# 12     ['What', 'did', 'you', 'learn', 'about', 'the'...
# ...                                                  ...
# 52856  ['Was', 'your', 'girlfriend', 'who', 'was', 'd...
# 52858  ['And', 'your', 'girlfriend', 'too', 'was', 't...
# 52860  ['Did', 'you', 'find', 'courage', 'during', 'y...
# 52862  ['So', 'what', 'happened', 'next', 'after', 'y...
# 52870  ['Who', 'were', 'the', 'French', 'soldiers', '...
#
#                                              added_words  \
# a
# 4                                                     []
# 6                                                     []
# 8      ['when', 'soviets', 'to', 'the', 'estonia', '1...
# 10     ['it', 'mean', 'the', 'of', 'gymnasium', 'is',...
# 12     ['your', 'what', 'did', 'about', 'learn', 'you...
# ...                                                  ...
# 52856  ['deported', 'your', 'girlfriend', 'you', 'wit...
# 52858                             ['girlfriend', 'your']
# 52860  ['imprisonment', 'during', 'your', 'or', 'libe...
# 52862  ['next', 'after', 'what', 'you', 'happened', '...
# 52870  ['during', 'the', 'soldiers', 'liberation', 's...
#
#                         removed_words added_length removed_length  \
# a
# 4                                  []            0              0
# 6                                  []            0              0
# 8                                  []            7              0
# 10                   ['means', 'the']           10              2
# 12                                 []            9              0
# ...                               ...          ...            ...
# 52856  ['she', 'girl', 'a', 'friend']            7              4
# 52858                         ['she']            2              1
# 52860                       ['found']            8              1
# 52862                              []            7              0
# 52870                        ['they']            7              1
#
#        final_length is_flagged         flag_reasoning Overwritten  \
# a
# 4                76      FALSE
# 6                52      FALSE
# 8                19       TRUE  contains only numbers
# 10               17      FALSE
# 12               12      FALSE
# ...             ...        ...                    ...         ...
# 52856             9      FALSE
# 52858            10      FALSE
# 52860             9      FALSE
# 52862             8      FALSE
# 52870            11       TRUE              mentioned
#
#       Rewritten Flagged Question
# a
# 4
# 6
# 8
# 10
# 12
# ...                          ...
# 52856
# 52858
# 52860
# 52862
# 52870
#
# [15808 rows x 43 columns]

# %%
#@title Define Generic Prompting Function.
from openai import OpenAI
from pydantic import BaseModel, Field
from pydantic import TypeAdapter
from typing import List
from textwrap import dedent
import json

# Pass the API key to Open AI
client = OpenAI(api_key=os.environ.get("OPEN_AI_KEY"))


class ResponseTemplate(BaseModel):
  response: str = Field(
        ...,
        description="the response"
    )


# Define a wrapper function to call Open AI
def prompt_gpt(prompt,
               model = "gpt-4o-mini",
               max_tokens = 4096,
               temperature = 0.9,
               top_p = 0.9,
               response_format= ResponseTemplate,
               frequency_penalty = 0.2,
               presence_penalty = 0.0,
               system="Your role is to process data factually without generating hallucinations or fabrications"):
    '''
    Wrapper for querying the GPT API with a single function.

    Args:
        prompt (str): The query sent to the model API.
        model (str, optional): The version of GPT to be queried. Defaults to "gpt-4o-mini".
        max_tokens (int, optional): The maximum number of tokens to generate. Defaults to 4096.
        temperature (float, optional): The sampling temperature to use. Defaults to 0.9.
        top_p (float, optional): The nucleus sampling parameter. Defaults to 0.1.
        frequency_penalty (float, optional): The penalty for token frequency. Defaults to 0.2.
        presence_penalty (float, optional): The penalty for token presence. Defaults to 0.0.
        system (str, optional): The system-level prompt that defines the model's role.

    Returns:
        str: The text response generated by the model.
    '''
    response = client.beta.chat.completions.parse(
        model=model,
        messages=[
            {"role": "system", "content": system},
            {"role": "user", "content": dedent(prompt)}
        ],
        response_format= response_format,
        temperature=temperature,
        max_tokens=max_tokens,
        top_p=top_p,
        frequency_penalty=frequency_penalty,
        presence_penalty=presence_penalty,
    )

    output = response.choices[0].message.parsed

    # Dump the model to a dictionary with JSON-compatible formatting
    output_dict = output.model_dump(mode='json')

    # Return the dictionary with indentation using json.dumps()
    return output_dict

# %%
class ResponseFormat(BaseModel):
  rewritten_question: str = Field(..., description="The rewritten question")

prompt = "rewrite the following question to remove uneccessary words. question: {}"

# %%
def process_flags_row(index, row, df, prompt, response_format):
  questions = ['who', 'what', 'where', 'when', 'why', 'how', 'here']
  flagged_words = ['experience', 'considering', 'especially', 'given', 'particularly', 'relation', 'regarding', 'circumstances', 'suggesting', 'mentioned']
  if "One word elaboration" in row['flag_reasoning']:
    if any(word in row['text'].lower() for word in questions):
      df.at[index, 'Overwritten'] = False
    else:
      df.at[index, 'Overwritten'] = True
      df.at[index, 'Rewritten Flagged Question'] = row['text']
  elif any(word in row['flag_reasoning'].lower() for word in flagged_words):
    # Assuming 'prompt' is defined elsewhere
    prompt = prompt.format(row['final_text'])
    # Assuming 'prompt_gpt', 'ResponseFormat' are defined elsewhere
    rewritten_question = prompt_gpt(prompt, response_format=ResponseFormat, model = "gpt-4o-mini")
    df.at[index, 'Overwritten'] = True
    df.at[index, 'Rewritten Flagged Question'] = rewritten_question['rewritten_question']
  elif row['is_flagged'] == "FALSE":
    df.at[index, 'Overwritten'] = False
  else:
    df.at[index, 'Overwritten'] = "needs manual revision"

# %%
def process_flags(df, prompt, response_format):
  index = 1
  final = len(df)
  # Use tqdm to create a progress bar
  pbar = tqdm(df.iterrows())
  for idx, row in pbar:
      process_flags_row(idx, row, df, prompt, response_format)
      pbar.set_description(f"Processing row {index} of {final}")
      index += 1

# %%
process_flags(final_df, prompt, ResponseFormat)
# Out:
# Processing row 15808 of 15808: : 15808it [09:41, 27.16it/s]

# %%
final_df.to_csv("final_results.csv")

from google.colab import files
files.download("final_results.csv")
